# %% [markdown]
# ### **1. Create Conda Environment**

# %%
# Install Conda First
# Cell 1: Install condacolab
# !pip install -q condacolab
import condacolab
condacolab.install()

# %%
# Cell 2 (after restart): Create environment
# !conda create -n colab_notebook python=3.11 -y

# %% [markdown]
# ### **2. Activate Environment**

# %%
# Run something inside your conda environment
# !conda run -n colab_notebook python --version

# Activation does NOT persist

# %% [markdown]
# ### **3. Install Libraries**

# %%
# After changing kernel, install directly
# !conda install numpy pandas matplotlib seaborn scikit-learn tensorflow pytorch scikit-learn jupyter -y

# %% [markdown]
# ### **4. Import Libraries in Python File**

# %%
# Core scientific libraries
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Deep Learning
import tensorflow as tf
import torch

# Jupyter (only needed in notebooks)
from IPython.display import display

# %% [markdown]
# ### **5. Deactivate current environment**

# %%
# Or just restart runtime: Runtime → Restart runtime
# There is no proper activate/deactivate workflow in Colab, because each ! command runs in a separate shell session.
# !command runs in a temporary shell
# Activation does NOT persist
# There is nothing to deactivate

# %% [markdown]
# ### **6. Remove Environment**

# %%
# Step 1: Restart Runtime
# Runtime → Restart runtime (Restart Session)

# Step 2: Then remove the environment
# !conda env remove -n colab_notebook -y


# Verify removal
# !conda env list
