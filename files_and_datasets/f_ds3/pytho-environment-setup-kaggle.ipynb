# %% [markdown]
# ### **1. Check Available Packages**

# %%
# See what's already installed
# !pip list

# %% [markdown]
# ### **2. Install Additional Libraries**

# %%
# Install using pip only
# !pip install some-package-name
# !pip install numpy pandas matplotlib seaborn scikit-learn tensorflow pytorch scikit-learn jupyter
